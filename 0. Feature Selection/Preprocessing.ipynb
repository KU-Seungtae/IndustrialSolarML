# %%
import os
import warnings
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Configure environment
warnings.filterwarnings("ignore")

# Set random seed
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# Load dataset
file_path = os.path.join(os.getcwd(), "multiwafer_database_raw.xlsx")
data = pd.read_excel(file_path)

selected_features_raw = [
    "Dark Area %",
    "Defect Area %",
    "Grain Defect Area %",
    "Average Life Time",
    "Sigma Life Time",
    "Resistivity",
    "Wafer Area",
    "Vendor name",
]

TARGET_COL = "Efficiency"

# Output directory
output_dir = "Multiwafer_Database"
os.makedirs(output_dir, exist_ok=True)

# Utilities
def remove_groupwise_outliers(
    df: pd.DataFrame,
    group_col: str,
    target_col: str,
    lower_q: float = 0.01,
    upper_q: float = 0.99,
    min_group_size: int = 30,
) -> pd.DataFrame:
    def _filter(g: pd.DataFrame) -> pd.DataFrame:
        if g.shape[0] < min_group_size:
            return g
        lo = g[target_col].quantile(lower_q)
        hi = g[target_col].quantile(upper_q)
        return g[(g[target_col] >= lo) & (g[target_col] <= hi)]

    return df.groupby(group_col, group_keys=False).apply(_filter)


# Iterative filtering (K-means + percentile trimming)
N_ITER = 100
N_GROUPS = 1000

df_iter = data.copy()

for i in range(1, N_ITER + 1):
    df_iter = df_iter.dropna(subset=selected_features_raw + [TARGET_COL]).reset_index(drop=True)

    # Match previous training flow: rename only X columns (not data.columns)
    X = df_iter[selected_features_raw].copy()
    X.columns = X.columns.str.replace(" ", "_")

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X.values)

    # Distance-based grouping via K-means clustering
    n_clusters_eff = min(N_GROUPS, X_scaled.shape[0])
    kmeans = KMeans(
        n_clusters=n_clusters_eff,
        random_state=RANDOM_STATE,
        n_init=10,
    )
    cluster_labels = kmeans.fit_predict(X_scaled)

    df_iter = df_iter.copy()
    df_iter["KMeans_Group"] = cluster_labels

    # Remove top/bottom 1% within each group
    df_iter = remove_groupwise_outliers(
        df=df_iter,
        group_col="KMeans_Group",
        target_col=TARGET_COL,
        lower_q=0.01,
        upper_q=0.99,
        min_group_size=30,
    ).reset_index(drop=True)

    save_path = os.path.join(output_dir, f"multiwafer_database_{i}.xlsx")
    df_iter.to_excel(save_path, index=False)

    print(f"[Iteration {i:03d}] saved -> {save_path}")
# Out:
# [Iteration 001] saved -> Multiwafer_Database/multiwafer_database_1.xlsx
# [Iteration 002] saved -> Multiwafer_Database/multiwafer_database_2.xlsx
# [Iteration 003] saved -> Multiwafer_Database/multiwafer_database_3.xlsx
# [Iteration 004] saved -> Multiwafer_Database/multiwafer_database_4.xlsx
# [Iteration 005] saved -> Multiwafer_Database/multiwafer_database_5.xlsx
# [Iteration 006] saved -> Multiwafer_Database/multiwafer_database_6.xlsx
# [Iteration 007] saved -> Multiwafer_Database/multiwafer_database_7.xlsx
# [Iteration 008] saved -> Multiwafer_Database/multiwafer_database_8.xlsx
# [Iteration 009] saved -> Multiwafer_Database/multiwafer_database_9.xlsx
# [Iteration 010] saved -> Multiwafer_Database/multiwafer_database_10.xlsx
# [Iteration 011] saved -> Multiwafer_Database/multiwafer_database_11.xlsx
# [Iteration 012] saved -> Multiwafer_Database/multiwafer_database_12.xlsx
# [Iteration 013] saved -> Multiwafer_Database/multiwafer_database_13.xlsx
# [Iteration 014] saved -> Multiwafer_Database/multiwafer_database_14.xlsx
# [Iteration 015] saved -> Multiwafer_Database/multiwafer_database_15.xlsx
# [Iteration 016] saved -> Multiwafer_Database/multiwafer_database_16.xlsx
# [Iteration 017] saved -> Multiwafer_Database/multiwafer_database_17.xlsx
# [Iteration 018] saved -> Multiwafer_Database/multiwafer_database_18.xlsx
# [Iteration 019] saved -> Multiwafer_Database/multiwafer_database_19.xlsx
# [Iteration 020] saved -> Multiwafer_Database/multiwafer_database_20.xlsx
# [Iteration 021] saved -> Multiwafer_Database/multiwafer_database_21.xlsx
# [Iteration 022] saved -> Multiwafer_Database/multiwafer_database_22.xlsx
# [Iteration 023] saved -> Multiwafer_Database/multiwafer_database_23.xlsx
# [Iteration 024] saved -> Multiwafer_Database/multiwafer_database_24.xlsx
# [Iteration 025] saved -> Multiwafer_Database/multiwafer_database_25.xlsx
# [Iteration 026] saved -> Multiwafer_Database/multiwafer_database_26.xlsx
# [Iteration 027] saved -> Multiwafer_Database/multiwafer_database_27.xlsx
# [Iteration 028] saved -> Multiwafer_Database/multiwafer_database_28.xlsx
# [Iteration 029] saved -> Multiwafer_Database/multiwafer_database_29.xlsx
# [Iteration 030] saved -> Multiwafer_Database/multiwafer_database_30.xlsx
# [Iteration 031] saved -> Multiwafer_Database/multiwafer_database_31.xlsx
# [Iteration 032] saved -> Multiwafer_Database/multiwafer_database_32.xlsx
# [Iteration 033] saved -> Multiwafer_Database/multiwafer_database_33.xlsx
# [Iteration 034] saved -> Multiwafer_Database/multiwafer_database_34.xlsx
# [Iteration 035] saved -> Multiwafer_Database/multiwafer_database_35.xlsx
# [Iteration 036] saved -> Multiwafer_Database/multiwafer_database_36.xlsx
# [Iteration 037] saved -> Multiwafer_Database/multiwafer_database_37.xlsx
# [Iteration 038] saved -> Multiwafer_Database/multiwafer_database_38.xlsx
# [Iteration 039] saved -> Multiwafer_Database/multiwafer_database_39.xlsx
# [Iteration 040] saved -> Multiwafer_Database/multiwafer_database_40.xlsx
# [Iteration 041] saved -> Multiwafer_Database/multiwafer_database_41.xlsx
# [Iteration 042] saved -> Multiwafer_Database/multiwafer_database_42.xlsx
# [Iteration 043] saved -> Multiwafer_Database/multiwafer_database_43.xlsx
# [Iteration 044] saved -> Multiwafer_Database/multiwafer_database_44.xlsx
# [Iteration 045] saved -> Multiwafer_Database/multiwafer_database_45.xlsx
# [Iteration 046] saved -> Multiwafer_Database/multiwafer_database_46.xlsx
# [Iteration 047] saved -> Multiwafer_Database/multiwafer_database_47.xlsx
# [Iteration 048] saved -> Multiwafer_Database/multiwafer_database_48.xlsx
# [Iteration 049] saved -> Multiwafer_Database/multiwafer_database_49.xlsx
# [Iteration 050] saved -> Multiwafer_Database/multiwafer_database_50.xlsx
# [Iteration 051] saved -> Multiwafer_Database/multiwafer_database_51.xlsx
# [Iteration 052] saved -> Multiwafer_Database/multiwafer_database_52.xlsx
# [Iteration 053] saved -> Multiwafer_Database/multiwafer_database_53.xlsx
# [Iteration 054] saved -> Multiwafer_Database/multiwafer_database_54.xlsx
# [Iteration 055] saved -> Multiwafer_Database/multiwafer_database_55.xlsx
# [Iteration 056] saved -> Multiwafer_Database/multiwafer_database_56.xlsx
# [Iteration 057] saved -> Multiwafer_Database/multiwafer_database_57.xlsx
# [Iteration 058] saved -> Multiwafer_Database/multiwafer_database_58.xlsx
# [Iteration 059] saved -> Multiwafer_Database/multiwafer_database_59.xlsx
# [Iteration 060] saved -> Multiwafer_Database/multiwafer_database_60.xlsx
# [Iteration 061] saved -> Multiwafer_Database/multiwafer_database_61.xlsx
# [Iteration 062] saved -> Multiwafer_Database/multiwafer_database_62.xlsx
# [Iteration 063] saved -> Multiwafer_Database/multiwafer_database_63.xlsx
# [Iteration 064] saved -> Multiwafer_Database/multiwafer_database_64.xlsx
# [Iteration 065] saved -> Multiwafer_Database/multiwafer_database_65.xlsx
# [Iteration 066] saved -> Multiwafer_Database/multiwafer_database_66.xlsx
# [Iteration 067] saved -> Multiwafer_Database/multiwafer_database_67.xlsx
# [Iteration 068] saved -> Multiwafer_Database/multiwafer_database_68.xlsx
# [Iteration 069] saved -> Multiwafer_Database/multiwafer_database_69.xlsx
# [Iteration 070] saved -> Multiwafer_Database/multiwafer_database_70.xlsx
# [Iteration 071] saved -> Multiwafer_Database/multiwafer_database_71.xlsx
# [Iteration 072] saved -> Multiwafer_Database/multiwafer_database_72.xlsx
# [Iteration 073] saved -> Multiwafer_Database/multiwafer_database_73.xlsx
# [Iteration 074] saved -> Multiwafer_Database/multiwafer_database_74.xlsx
# [Iteration 075] saved -> Multiwafer_Database/multiwafer_database_75.xlsx
# [Iteration 076] saved -> Multiwafer_Database/multiwafer_database_76.xlsx
# [Iteration 077] saved -> Multiwafer_Database/multiwafer_database_77.xlsx
# [Iteration 078] saved -> Multiwafer_Database/multiwafer_database_78.xlsx
# [Iteration 079] saved -> Multiwafer_Database/multiwafer_database_79.xlsx
# [Iteration 080] saved -> Multiwafer_Database/multiwafer_database_80.xlsx
# [Iteration 081] saved -> Multiwafer_Database/multiwafer_database_81.xlsx
# [Iteration 082] saved -> Multiwafer_Database/multiwafer_database_82.xlsx
# [Iteration 083] saved -> Multiwafer_Database/multiwafer_database_83.xlsx
# [Iteration 084] saved -> Multiwafer_Database/multiwafer_database_84.xlsx
# [Iteration 085] saved -> Multiwafer_Database/multiwafer_database_85.xlsx
# [Iteration 086] saved -> Multiwafer_Database/multiwafer_database_86.xlsx
# [Iteration 087] saved -> Multiwafer_Database/multiwafer_database_87.xlsx
# [Iteration 088] saved -> Multiwafer_Database/multiwafer_database_88.xlsx
# [Iteration 089] saved -> Multiwafer_Database/multiwafer_database_89.xlsx
# [Iteration 090] saved -> Multiwafer_Database/multiwafer_database_90.xlsx
# [Iteration 091] saved -> Multiwafer_Database/multiwafer_database_91.xlsx
# [Iteration 092] saved -> Multiwafer_Database/multiwafer_database_92.xlsx
# [Iteration 093] saved -> Multiwafer_Database/multiwafer_database_93.xlsx
# [Iteration 094] saved -> Multiwafer_Database/multiwafer_database_94.xlsx
# [Iteration 095] saved -> Multiwafer_Database/multiwafer_database_95.xlsx
# [Iteration 096] saved -> Multiwafer_Database/multiwafer_database_96.xlsx
# [Iteration 097] saved -> Multiwafer_Database/multiwafer_database_97.xlsx
# [Iteration 098] saved -> Multiwafer_Database/multiwafer_database_98.xlsx
# [Iteration 099] saved -> Multiwafer_Database/multiwafer_database_99.xlsx
# [Iteration 100] saved -> Multiwafer_Database/multiwafer_database_100.xlsx
